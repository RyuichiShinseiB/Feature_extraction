# %%
# Standard Library
from pathlib import Path

# Third Party Library
import matplotlib.pyplot as plt

# First Party Library
from src.utilities import load_model
from src.visualization.weight import (
    make_tiled_kernel_dict,
    save_tiled_kernel_images,
    visualize_cnn_kernels,
)

# %%
model_name = "SimpleCAE16"
date = "2023-11-27"
time = "12-07-16"
model_saved_dir = Path("..") / "models" / model_name / date / time
dst_dir = Path("..") / "reports" / "figures" / model_name / date / time / "visualized_kernels"

model16 = load_model(model_saved_dir)

tiled_params16 = make_tiled_kernel_dict(model16)
fig = visualize_cnn_kernels(tiled_params16)
plt.show()
save_tiled_kernel_images(tiled_params16, dst_dir)
# Out:
# Configurations obtained during training.
# Loading model parameters

# %%
model_name = "SimpleCAE32"
date = "2023-07-10"
time = "12-37-46"
model_saved_dir = Path("..") / "models" / model_name / date / time
dst_dir = Path("..") / "reports" / "figures" / model_name / date / time / "visualized_kernels"


model32 = load_model(model_saved_dir)

tiled_params32 = make_tiled_kernel_dict(model32)
fig = visualize_cnn_kernels(tiled_params32)
plt.show()
save_tiled_kernel_images(tiled_params32, dst_dir)
# Out:
# Configurations obtained during training.
# Loading model parameters

# %%
model_name = "SimpleCAE64"
date = "2023-07-21"
time = "20-18-22"
model_saved_dir = Path("..") / "models" / model_name / date / time
dst_dir = Path("..") / "reports" / "figures" / model_name / date / time / "visualized_kernels"

model64 = load_model(model_saved_dir)

tiled_params64 = make_tiled_kernel_dict(model64)
fig = visualize_cnn_kernels(tiled_params64)
plt.show()
save_tiled_kernel_images(tiled_params64, dst_dir)
# Out:
# Configurations obtained during training.
# Loading model parameters
